# %%
import numpy as np
import pandas as pd
import itertools
import seaborn as sns
import matplotlib.pyplot as plt

pd.options.display.float_format = '{:,.2f}'.format

# %%
data = pd.DataFrame([
    {
        'Cf': 2e4,
        'N': 2,
        'MS': 0.989,
        'sigmaS': 0.003
    },
    {
        'Cf': 2e4,
        'N': 4,
        'MS': 1.313,
        'sigmaS': 0.004
    },
    {
        'Cf': 2e4,
        'N': 8,
        'MS': 1.571,
        'sigmaS': 0.004
    },
    {
        'Cf': 2e4,
        'N': 16,
        'MS': 1.743,
        'sigmaS': 0.005
    },
    {
        'Cf': 2e4,
        'N': 32,
        'MS': 1.843,
        'sigmaS': 0.005
    },
    {
        'Cf': 2e4,
        'N': 64,
        'MS': 1.899,
        'sigmaS': 0.005
    },
    {
        'Cf': 2e4,
        'N': 128,
        'MS': 1.928,
        'sigmaS': 0.005
    },
    {
        'Cf': 2e4,
        'N': 256,
        'MS': 1.942,
        'sigmaS': 0.005
    },
    {
        'Cf': 2e6,
        'N': 2,
        'MS': 1.977,
        'sigmaS': 0.008
    },
    {
        'Cf': 2e6,
        'N': 4,
        'MS': 3.902,
        'sigmaS': 0.016
    },
    {
        'Cf': 2e6,
        'N': 8,
        'MS': 7.608,
        'sigmaS': 0.032
    },
    {
        'Cf': 2e6,
        'N': 16,
        'MS': 14.565,
        'sigmaS': 0.091
    },
    {
        'Cf': 2e6,
        'N': 32,
        'MS': 26.742,
        'sigmaS': 0.188
    },
    {
        'Cf': 2e6,
        'N': 64,
        'MS': 46.467,
        'sigmaS': 0.409
    },
    {
        'Cf': 2e6,
        'N': 128,
        'MS': 73.593,
        'sigmaS': 0.548
    },
    {
        'Cf': 2e6,
        'N': 256,
        'MS': 105.029,
        'sigmaS': 0.852
    },
])

# %%
data[data['Cf'] == 2e6]
# Out:
#              Cf    N     MS  sigmaS
# 8  2,000,000.00    2   1.98    0.01
# 9  2,000,000.00    4   3.90    0.02
# 10 2,000,000.00    8   7.61    0.03
# 11 2,000,000.00   16  14.56    0.09
# 12 2,000,000.00   32  26.74    0.19
# 13 2,000,000.00   64  46.47    0.41
# 14 2,000,000.00  128  73.59    0.55
# 15 2,000,000.00  256 105.03    0.85

# %%
fig = plt.figure(figsize=(10,8))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('N')
ax1.set_ylabel('MS')
marker_size = 80
ax1.scatter(
    data[data['Cf'] == 2e6]['N'],
    data[data['Cf'] == 2e6]['MS'],
    label='Cf=2e6',
    marker='o',
    s=marker_size
)
ax1.plot(
    data[data['Cf'] == 2e6]['N'],
    data[data['Cf'] == 2e6]['MS']
)
plt.grid()
#plt.title('Зависимость ускорения S от количества процессоров N для различных Cf (декомпозиция узлов)')
plt.legend(loc='upper left')
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('N')
ax1.set_ylabel('sigma S')
marker_size = 80
ax1.scatter(
    data[data['Cf'] == 2e6]['N'],
    data[data['Cf'] == 2e6]['sigmaS'],
    label='Cf=2e6',
    marker='s',
    s=marker_size
)
ax1.plot(
    data[data['Cf'] == 2e6]['N'],
    data[data['Cf'] == 2e6]['sigmaS']
)
plt.grid()
#plt.title('Зависимость ускорения S от количества процессоров N для различных Cf (декомпозиция узлов)')
plt.legend(loc='upper left')
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('N')
ax1.set_ylabel('MS')
marker_size = 80
ax1.scatter(
    data[data['Cf'] == 2e4]['N'],
    data[data['Cf'] == 2e4]['MS'],
    label='Cf=2e4',
    marker='o',
    s=marker_size
)
ax1.plot(
    data[data['Cf'] == 2e4]['N'],
    data[data['Cf'] == 2e4]['MS']
)
plt.grid()
#plt.title('Зависимость ускорения S от количества процессоров N для различных Cf (декомпозиция узлов)')
plt.legend(loc='upper left')
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('N')
ax1.set_ylabel('sigma S')
marker_size = 80
ax1.scatter(
    data[data['Cf'] == 2e4]['N'],
    data[data['Cf'] == 2e4]['sigmaS'],
    label='Cf=2e4',
    marker='s',
    s=marker_size
)
ax1.plot(
    data[data['Cf'] == 2e4]['N'],
    data[data['Cf'] == 2e4]['sigmaS']
)
plt.grid()
#plt.title('Зависимость ускорения S от количества процессоров N для различных Cf (декомпозиция узлов)')
plt.legend(loc='upper left')
plt.show()
