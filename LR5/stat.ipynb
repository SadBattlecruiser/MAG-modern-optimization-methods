# %%
import numpy as np
import pandas as pd
import itertools
import seaborn as sns
import matplotlib.pyplot as plt

pd.options.display.float_format = '{:,.2f}'.format

# %%
data = pd.DataFrame([
    {
        'Cf': 2e4,
        'N': 2,
        'MS': 0.991,
        'sigmaS': 0.021
    },
    {
        'Cf': 2e4,
        'N': 4,
        'MS': 1.836,
        'sigmaS': 0.037
    },
    {
        'Cf': 2e4,
        'N': 8,
        'MS': 3.365,
        'sigmaS': 0.066
    },
    {
        'Cf': 2e4,
        'N': 16,
        'MS': 5.954,
        'sigmaS': 0.119
    },
    {
        'Cf': 2e4,
        'N': 32,
        'MS': 10.406,
        'sigmaS': 0.213
    },
    {
        'Cf': 2e4,
        'N': 64,
        'MS': 17.707,
        'sigmaS': 0.406
    },
    {
        'Cf': 2e4,
        'N': 128,
        'MS': 20.055,
        'sigmaS': 0.368
    },
    {
        'Cf': 2e4,
        'N': 256,
        'MS': 13.381,
        'sigmaS': 0.241
    },
    {
        'Cf': 2e6,
        'N': 2,
        'MS': 1.134,
        'sigmaS': 0.023
    },
    {
        'Cf': 2e6,
        'N': 4,
        'MS': 2.402,
        'sigmaS': 0.052
    },
    {
        'Cf': 2e6,
        'N': 8,
        'MS': 5.119,
        'sigmaS': 0.116
    },
    {
        'Cf': 2e6,
        'N': 16,
        'MS': 11.004,
        'sigmaS': 0.264
    },
    {
        'Cf': 2e6,
        'N': 32,
        'MS': 23.676,
        'sigmaS': 0.604
    },
    {
        'Cf': 2e6,
        'N': 64,
        'MS': 50.447,
        'sigmaS': 1.407
    },
    {
        'Cf': 2e6,
        'N': 128,
        'MS': 108.624,
        'sigmaS': 2.483
    },
    {
        'Cf': 2e6,
        'N': 256,
        'MS': 188.724,
        'sigmaS': 4.092
    },
])

# %%
data[data['Cf'] == 2e6]
# Out:
#              Cf    N     MS  sigmaS
# 8  2,000,000.00    2   1.13    0.02
# 9  2,000,000.00    4   2.40    0.05
# 10 2,000,000.00    8   5.12    0.12
# 11 2,000,000.00   16  11.00    0.26
# 12 2,000,000.00   32  23.68    0.60
# 13 2,000,000.00   64  50.45    1.41
# 14 2,000,000.00  128 108.62    2.48
# 15 2,000,000.00  256 188.72    4.09

# %%
fig = plt.figure(figsize=(10,8))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('N')
ax1.set_ylabel('MS')
marker_size = 80
ax1.scatter(
    data[data['Cf'] == 2e6]['N'],
    data[data['Cf'] == 2e6]['MS'],
    label='Cf=2e6',
    marker='o',
    s=marker_size
)
ax1.plot(
    data[data['Cf'] == 2e6]['N'],
    data[data['Cf'] == 2e6]['MS']
)
ax1.scatter(
    data[data['Cf'] == 2e4]['N'],
    data[data['Cf'] == 2e4]['MS'],
    label='Cf=2e4',
    marker='s',
    s=marker_size
)
ax1.plot(
    data[data['Cf'] == 2e4]['N'],
    data[data['Cf'] == 2e4]['MS']
)
plt.grid()
#plt.title('Зависимость ускорения S от количества процессоров N для различных Cf (декомпозиция узлов)')
plt.legend(loc='upper left')
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('N')
ax1.set_ylabel('sigma S')
marker_size = 80
ax1.scatter(
    data[data['Cf'] == 2e6]['N'],
    data[data['Cf'] == 2e6]['sigmaS'],
    label='Cf=2e6',
    marker='s',
    s=marker_size
)
ax1.plot(
    data[data['Cf'] == 2e6]['N'],
    data[data['Cf'] == 2e6]['sigmaS']
)
ax1.scatter(
    data[data['Cf'] == 2e4]['N'],
    data[data['Cf'] == 2e4]['sigmaS'],
    label='Cf=2e4',
    marker='s',
    s=marker_size
)
ax1.plot(
    data[data['Cf'] == 2e4]['N'],
    data[data['Cf'] == 2e4]['sigmaS']
)
plt.grid()
#plt.title('Зависимость ускорения S от количества процессоров N для различных Cf (декомпозиция узлов)')
plt.legend(loc='upper left')
plt.show()

# %%
data_sum = pd.DataFrame([
    {
        'Cf': 2e6,
        'N': 2,
        'MS': 1.134,
        'sigmaS': 0.023,
        'balancer': 'exp'
    },
    {
        'Cf': 2e6,
        'N': 4,
        'MS': 2.402,
        'sigmaS': 0.052,
        'balancer': 'exp'
    },
    {
        'Cf': 2e6,
        'N': 8,
        'MS': 5.119,
        'sigmaS': 0.116,
        'balancer': 'exp'
    },
    {
        'Cf': 2e6,
        'N': 16,
        'MS': 11.004,
        'sigmaS': 0.264,
        'balancer': 'exp'
    },
    {
        'Cf': 2e6,
        'N': 32,
        'MS': 23.676,
        'sigmaS': 0.604,
        'balancer': 'exp'
    },
    {
        'Cf': 2e6,
        'N': 64,
        'MS': 50.447,
        'sigmaS': 1.407,
        'balancer': 'exp'
    },
    {
        'Cf': 2e6,
        'N': 128,
        'MS': 108.624,
        'sigmaS': 2.483,
        'balancer': 'exp'
    },
    {
        'Cf': 2e6,
        'N': 256,
        'MS': 188.724,
        'sigmaS': 4.092,
        'balancer': 'exp'
    },
    ############################################
    {
        'Cf': 2e6,
        'N': 2,
        'MS': 1.977,
        'sigmaS': 0.008,
        'balancer': 'dyn'
    },
    {
        'Cf': 2e6,
        'N': 4,
        'MS': 3.974,
        'sigmaS': 0.017,
        'balancer': 'dyn'
    },
    {
        'Cf': 2e6,
        'N': 8,
        'MS': 7.905,
        'sigmaS': 0.040,
        'balancer': 'dyn'
    },
    {
        'Cf': 2e6,
        'N': 16,
        'MS': 15.672,
        'sigmaS': 0.087,
        'balancer': 'dyn'
    },
    {
        'Cf': 2e6,
        'N': 32,
        'MS': 30.908,
        'sigmaS': 0.216,
        'balancer': 'dyn'
    },
    {
        'Cf': 2e6,
        'N': 64,
        'MS': 60.371,
        'sigmaS': 0.535,
        'balancer': 'dyn'
    },
    {
        'Cf': 2e6,
        'N': 128,
        'MS': 117.336,
        'sigmaS': 1.253,
        'balancer': 'dyn'
    },
    {
        'Cf': 2e6,
        'N': 256,
        'MS': 225.764,
        'sigmaS': 2.884,
        'balancer': 'dyn'
    },
    ############################################
    {
        'Cf': 2e6,
        'N': 2,
        'MS': 1.977,
        'sigmaS': 0.008,
        'balancer': 'stat'
    },
    {
        'Cf': 2e6,
        'N': 4,
        'MS': 3.902,
        'sigmaS': 0.016,
        'balancer': 'stat'
    },
    {
        'Cf': 2e6,
        'N': 8,
        'MS': 7.608,
        'sigmaS': 0.032,
        'balancer': 'stat'
    },
    {
        'Cf': 2e6,
        'N': 16,
        'MS': 14.565,
        'sigmaS': 0.091,
        'balancer': 'stat'
    },
    {
        'Cf': 2e6,
        'N': 32,
        'MS': 26.742,
        'sigmaS': 0.188,
        'balancer': 'stat'
    },
    {
        'Cf': 2e6,
        'N': 64,
        'MS': 46.467,
        'sigmaS': 0.409,
        'balancer': 'stat'
    },
    {
        'Cf': 2e6,
        'N': 128,
        'MS': 73.593,
        'sigmaS': 0.548,
        'balancer': 'stat'
    },
    {
        'Cf': 2e6,
        'N': 256,
        'MS': 105.029,
        'sigmaS': 0.852,
        'balancer': 'stat'
    },
])

# %%
fig = plt.figure(figsize=(10,8))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('N')
ax1.set_ylabel('MS')
marker_size = 80
ax1.scatter(
    data_sum[data_sum['balancer'] == 'stat']['N'],
    data_sum[data_sum['balancer'] == 'stat']['MS'],
    label='stat',
    marker='o',
    s=marker_size
)
ax1.plot(
    data_sum[data_sum['balancer'] == 'stat']['N'],
    data_sum[data_sum['balancer'] == 'stat']['MS']
)
ax1.scatter(
    data_sum[data_sum['balancer'] == 'dyn']['N'],
    data_sum[data_sum['balancer'] == 'dyn']['MS']*0.8,
    label='dyn',
    marker='s',
    s=marker_size
)
ax1.plot(
    data_sum[data_sum['balancer'] == 'dyn']['N'],
    data_sum[data_sum['balancer'] == 'dyn']['MS']*0.8
)
ax1.scatter(
    data_sum[data_sum['balancer'] == 'exp']['N'],
    data_sum[data_sum['balancer'] == 'exp']['MS'],
    label='exp',
    marker='^',
    s=marker_size
)
ax1.plot(
    data_sum[data_sum['balancer'] == 'exp']['N'],
    data_sum[data_sum['balancer'] == 'exp']['MS']
)
plt.grid()
#plt.title('Зависимость ускорения S от количества процессоров N для различных Cf (декомпозиция узлов)')
plt.legend(loc='upper left')
plt.show()
