# %%
import numpy as np
import pandas as pd
import itertools
import seaborn as sns
import matplotlib.pyplot as plt

pd.options.display.float_format = '{:,.2f}'.format

# %%
data = pd.DataFrame([
    {
        'Cf': 2e4,
        'N': 2,
        'MS': 1.915,
        'sigmaS': 0.007
    },
    {
        'Cf': 2e4,
        'N': 4,
        'MS': 3.613,
        'sigmaS': 0.016
    },
    {
        'Cf': 2e4,
        'N': 8,
        'MS': 6.676,
        'sigmaS': 0.031
    },
    {
        'Cf': 2e4,
        'N': 16,
        'MS': 12.076,
        'sigmaS': 0.052
    },
    {
        'Cf': 2e4,
        'N': 32,
        'MS': 21.164,
        'sigmaS': 0.119
    },
    {
        'Cf': 2e4,
        'N': 64,
        'MS': 36.103,
        'sigmaS': 0.222
    },
    {
        'Cf': 2e4,
        'N': 128,
        'MS': 59.491,
        'sigmaS': 0.364
    },
    {
        'Cf': 2e4,
        'N': 256,
        'MS': 94.003,
        'sigmaS': 0.549
    },
    {
        'Cf': 2e6,
        'N': 2,
        'MS': 1.977,
        'sigmaS': 0.008
    },
    {
        'Cf': 2e6,
        'N': 4,
        'MS': 3.974,
        'sigmaS': 0.017
    },
    {
        'Cf': 2e6,
        'N': 8,
        'MS': 7.905,
        'sigmaS': 0.040
    },
    {
        'Cf': 2e6,
        'N': 16,
        'MS': 15.672,
        'sigmaS': 0.087
    },
    {
        'Cf': 2e6,
        'N': 32,
        'MS': 30.908,
        'sigmaS': 0.216
    },
    {
        'Cf': 2e6,
        'N': 64,
        'MS': 60.371,
        'sigmaS': 0.535
    },
    {
        'Cf': 2e6,
        'N': 128,
        'MS': 117.336,
        'sigmaS': 1.253
    },
    {
        'Cf': 2e6,
        'N': 256,
        'MS': 225.764,
        'sigmaS': 2.884
    },
])

# %%
data[data['Cf'] == 2e6]
# Out:
#              Cf    N     MS  sigmaS
# 8  2,000,000.00    2   1.98    0.01
# 9  2,000,000.00    4   3.97    0.02
# 10 2,000,000.00    8   7.91    0.04
# 11 2,000,000.00   16  15.67    0.09
# 12 2,000,000.00   32  30.91    0.22
# 13 2,000,000.00   64  60.37    0.54
# 14 2,000,000.00  128 117.34    1.25
# 15 2,000,000.00  256 225.76    2.88

# %%
fig = plt.figure(figsize=(10,8))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('N')
ax1.set_ylabel('MS')
marker_size = 80
ax1.scatter(
    data[data['Cf'] == 2e6]['N'],
    data[data['Cf'] == 2e6]['MS'],
    label='Cf=2e6',
    marker='o',
    s=marker_size
)
ax1.plot(
    data[data['Cf'] == 2e6]['N'],
    data[data['Cf'] == 2e6]['MS']
)
ax1.scatter(
    data[data['Cf'] == 2e4]['N'],
    data[data['Cf'] == 2e4]['MS'],
    label='Cf=2e4',
    marker='s',
    s=marker_size
)
ax1.plot(
    data[data['Cf'] == 2e4]['N'],
    data[data['Cf'] == 2e4]['MS']
)
plt.grid()
#plt.title('Зависимость ускорения S от количества процессоров N для различных Cf (декомпозиция узлов)')
plt.legend(loc='upper left')
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
ax1 = fig.add_subplot(111)
ax1.set_xlabel('N')
ax1.set_ylabel('sigma S')
marker_size = 80
ax1.scatter(
    data[data['Cf'] == 2e6]['N'],
    data[data['Cf'] == 2e6]['sigmaS'],
    label='Cf=2e6',
    marker='s',
    s=marker_size
)
ax1.plot(
    data[data['Cf'] == 2e6]['N'],
    data[data['Cf'] == 2e6]['sigmaS']
)
ax1.scatter(
    data[data['Cf'] == 2e4]['N'],
    data[data['Cf'] == 2e4]['sigmaS'],
    label='Cf=2e4',
    marker='s',
    s=marker_size
)
ax1.plot(
    data[data['Cf'] == 2e4]['N'],
    data[data['Cf'] == 2e4]['sigmaS']
)
plt.grid()
#plt.title('Зависимость ускорения S от количества процессоров N для различных Cf (декомпозиция узлов)')
plt.legend(loc='upper left')
plt.show()
